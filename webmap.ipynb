# %% [markdown]
# # VOLCANOS

# %%
# Importing the nessassery libraries
import folium
import pandas as pd

# %%
### Reading info from Volcano data file
df = pd.read_csv('Volcanoes.txt')
df
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %% [markdown]
# ### Getting information from dataframe and zip them

# %%
### Getting information from dataframe and zip them
lat = list(df['LAT'])
lon = list(df['LON'])
name = list(df['NAME'])
elev = list(df['ELEV'])
coordinats = zip(lat, lon, name, elev)
elev[0]
# Out:
# 3285.0

# %%
# Making a object of the folium Map
map = folium.Map(location=[45.305561, -75.932418],zoom_start=3)

# %%
fg = folium.FeatureGroup(name= "My Map")
# fg.add_child(folium.Marker(location=[45.305561, -75.932418], popup='Hi Marker', icon=folium.Icon(color='red')))
# fg.add_child(folium.Marker(location=[65.305561, -51.932418], popup='Hi Marker', icon=folium.Icon(color='blue')))

# %%
### Making map colorful by defining the color for each elevation, and call it in forLoop as icon colors
def colors(elev):
    color = ''
    if elev <= 1000:
        color = 'red'
    elif elev <= 2000:
        color = 'blue'
    elif elev <= 3000:
        color = 'yellow'
    else:
        color = 'green'
    return color

# %%
for lat, lon, name, elev in coordinats:
    fg.add_child(folium.Marker(location=[lat, lon], popup= str(elev)+' , '+name, icon=folium.Icon(color= colors(elev))))
# Out:
# <ipython-input-98-54d1083e93b2>:2: UserWarning: color argument of Icon should be one of: {'blue', 'lightgreen', 'lightred', 'gray', 'black', 'pink', 'darkblue', 'darkred', 'cadetblue', 'lightblue', 'purple', 'orange', 'red', 'white', 'green', 'darkgreen', 'lightgray', 'darkpurple', 'beige'}.
#   fg.add_child(folium.Marker(location=[lat, lon], popup= str(elev)+' , '+name, icon=folium.Icon(color= colors(elev))))

# %%
map.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#### Saving the map to HTML file
map.save("Map1.html")
